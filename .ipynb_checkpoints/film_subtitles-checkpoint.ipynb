# %% [markdown]
# # Загрузка данных и библиотек

# %%
import pandas as pd
import numpy as np
from sklearn.datasets import load_files
import srt
import matplotlib.pyplot as plt
import seaborn as sns
import nltk
from nltk.stem import WordNetLemmatizer
from wordcloud import WordCloud, STOPWORDS
from PIL import Image
from datasets import Dataset,DatasetDict
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import f1_score
from sklearn.ensemble import RandomForestClassifier
import xgboost as xgb
from sklearn.preprocessing import LabelEncoder
#nltk.download('stopwords')
#nltk.download('wordnet')
#nltk.download('omw-1.4')

sns.set()
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
import logging
logger = logging.getLogger()
logger.setLevel(logging.CRITICAL)

# %%
movie_labels = pd.read_excel('movies_labels.xlsx', names=['id', 'movie', 'level']).drop('id', axis=1)
subtitles_files = load_files('Subtitles/', shuffle=False)

# %%
print(movie_labels.info())
movie_labels.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 241 entries, 0 to 240
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   movie   241 non-null    object
#  1   level   241 non-null    object
# dtypes: object(2)
# memory usage: 3.9+ KB
# None
#                               movie   level
# 0         10_Cloverfield_lane(2016)      B1
# 1  10_things_I_hate_about_you(1999)      B1
# 2              A_knights_tale(2001)      B2
# 3              A_star_is_born(2018)      B2
# 4                     Aladdin(1992)  A2/A2+

# %%
subtitles = pd.DataFrame(data={'data': subtitles_files.data, 
                          'filenames': subtitles_files.filenames})
subtitles.head()
# Out:
#                                                 data  \
# 0  b'1\n00:00:03,169 --> 00:00:05,171\n( bugs chi...
# 1  b'1\n00:00:03,045 --> 00:00:05,047\n- ( birds ...
# 2  b'1\n00:00:03,003 --> 00:00:04,671\n( thunder ...
# 3  b'1\n00:00:03,045 --> 00:00:05,422\n( birds ch...
# 4  b"1\n00:00:03,420 --> 00:00:04,922\n- ( walkie...
#
#                                            filenames
# 0  Subtitles/A2\The Walking Dead-S01E01-Days Gone...
# 1  Subtitles/A2\The Walking Dead-S01E02-Guts.Engl...
# 2  Subtitles/A2\The Walking Dead-S01E03-Tell It T...
# 3  Subtitles/A2\The Walking Dead-S01E04-Vatos.Eng...
# 4  Subtitles/A2\The Walking Dead-S01E05-Wildfire....

# %% [markdown]
# # Предобработка данных

# %% [markdown]
# ## subtitles

# %%
subtitles.head()
# Out:
#                                                 data  \
# 0  b'1\n00:00:03,169 --> 00:00:05,171\n( bugs chi...
# 1  b'1\n00:00:03,045 --> 00:00:05,047\n- ( birds ...
# 2  b'1\n00:00:03,003 --> 00:00:04,671\n( thunder ...
# 3  b'1\n00:00:03,045 --> 00:00:05,422\n( birds ch...
# 4  b"1\n00:00:03,420 --> 00:00:04,922\n- ( walkie...
#
#                                            filenames
# 0  Subtitles/A2\The Walking Dead-S01E01-Days Gone...
# 1  Subtitles/A2\The Walking Dead-S01E02-Guts.Engl...
# 2  Subtitles/A2\The Walking Dead-S01E03-Tell It T...
# 3  Subtitles/A2\The Walking Dead-S01E04-Vatos.Eng...
# 4  Subtitles/A2\The Walking Dead-S01E05-Wildfire....

# %%
subtitles['data'] = subtitles['data'].str.decode('ISO-8859-1')

# %% [markdown]
# Субтитры переведены из bytes в текстовый формат.

# %%
def get_name_and_level(row):
    level = row.split('\\')[0][10:]
    name = row.split('\\')[1][:-4]
    return pd.Series([name, level])

# %%
subtitles[['movie', 'level']] = subtitles['filenames'].apply(get_name_and_level)
subtitles = subtitles.drop('filenames', axis=1)

# %% [markdown]
# Из столбца `filenames` были получены названия фильмов и их уровень.

# %%
subtitles['movie'] = subtitles['movie'].str.lower()

# %%
subtitles.head()
# Out:
#                                                 data  \
# 0  1\n00:00:03,169 --> 00:00:05,171\n( bugs chitt...
# 1  1\n00:00:03,045 --> 00:00:05,047\n- ( birds ch...
# 2  1\n00:00:03,003 --> 00:00:04,671\n( thunder ru...
# 3  1\n00:00:03,045 --> 00:00:05,422\n( birds chir...
# 4  1\n00:00:03,420 --> 00:00:04,922\n- ( walkie-t...
#
#                                                movie level
# 0      the walking dead-s01e01-days gone bye.english    A2
# 1               the walking dead-s01e02-guts.english    A2
# 2  the walking dead-s01e03-tell it to the frogs.e...    A2
# 3              the walking dead-s01e04-vatos.english    A2
# 4           the walking dead-s01e05-wildfire.english    A2

# %%
subtitles[subtitles['data'].duplicated(keep=False)]
# Out:
#                                                   data  \
# 207  1\n00:01:25,210 --> 00:01:28,004\nI owe everyt...
# 208  1\n00:01:25,210 --> 00:01:28,004\nI owe everyt...
#
#                            movie      level
# 207  it_s_a_wonderful_life(1946)  Unlabeled
# 208   its_a_wonderful_life(1946)  Unlabeled

# %%
subtitles = subtitles.drop(subtitles[subtitles['data'].duplicated()].index, axis=0)

# %% [markdown]
# Удален дубликат субтитров.

# %% [markdown]
# ## movie_labels

# %%
movie_labels.isna().sum()
# Out:
# movie    0
# level    0
# dtype: int64

# %%
movie_labels.describe()
# Out:
#                movie level
# count            241   241
# unique           237     7
# top     Powder(1995)    B2
# freq               2   101

# %% [markdown]
# Пропуски отсутствуют, есть дубликаты.

# %% [markdown]
# ### movie

# %%
movie_labels['movie'] = movie_labels['movie'].str.lower()

# %%
movie_labels.duplicated().sum()
# Out:
# 2

# %%
movie_labels = movie_labels.drop_duplicates()

# %%
print(movie_labels[movie_labels['movie'].duplicated(keep=False)].index)
movie_labels[movie_labels['movie'].duplicated(keep=False)]
# Out:
# Int64Index([75, 83, 84, 99], dtype='int64')
#                    movie       level
# 75  the_blind_side(2009)          B2
# 83    the_terminal(2004)          B1
# 84  the_blind_side(2009)          B1
# 99    the_terminal(2004)  A2/A2+, B1

# %% [markdown]
# Исходя из информации в https://moviesbylevels.wordpress.com для фильма `The blind side` был выбран уровень B2

# %%
movie_labels = movie_labels.drop([84, 99], axis=0)

# %% [markdown]
# Дубликаты удалены.

# %% [markdown]
# ### level

# %%
movie_labels = movie_labels.reset_index(drop=True)

# %%
movie_labels['level'].value_counts()
# Out:
# B2            101
# B1             52
# C1             40
# A2/A2+         26
# B1, B2          8
# A2              6
# A2/A2+, B1      4
# Name: level, dtype: int64

# %%
indexes = movie_labels[movie_labels['level'] == 'A2/A2+, B1'].index
movie_labels[movie_labels['level'] == 'A2/A2+, B1']
# Out:
#                            movie       level
# 35            forrest_gump(1994)  A2/A2+, B1
# 39                     her(2013)  A2/A2+, B1
# 59            moulin_rouge(2001)  A2/A2+, B1
# 84  the_fault_in_our_stars(2014)  A2/A2+, B1

# %%
movie_labels['level'].iloc[indexes[0]] = 'A2'
movie_labels['level'].iloc[indexes[1]] = 'B1'
movie_labels['level'].iloc[indexes[2]] = 'B1'
movie_labels['level'].iloc[indexes[3]] = 'A2'

# %% [markdown]
# Исходя из личного опыта, уровни А2/A2+, B1 были изменены на:
# * `Forrest Gump` - A2;
# * `Her` - B1;
# * `Moulin rouge` - B1;
# * `The fault in our stars` - A2.

# %%
indexes = movie_labels[movie_labels['level'] == 'B1, B2'].index
movie_labels[movie_labels['level'] == 'B1, B2']
# Out:
#                              movie   level
# 13            before_sunrise(1995)  B1, B2
# 14             before_sunset(2004)  B1, B2
# 16       bridget_jones_diary(2001)  B1, B2
# 20       catch_me_if_you_can(2002)  B1, B2
# 49                      lion(2016)  B1, B2
# 80  the_shawshank_redemption(1994)  B1, B2
# 85              the_graduate(1967)  B1, B2
# 92     the_lord_of_the_rings(2001)  B1, B2

# %%
movie_labels['level'].iloc[indexes[0]] = 'B1'
movie_labels['level'].iloc[indexes[1]] = 'B1'
movie_labels['level'].iloc[indexes[2]] = 'B1'
movie_labels['level'].iloc[indexes[3]] = 'B2'
movie_labels['level'].iloc[indexes[4]] = 'B2'
movie_labels['level'].iloc[indexes[5]] = 'B2'
movie_labels['level'].iloc[indexes[6]] = 'B2'
movie_labels['level'].iloc[indexes[7]] = 'B1'

# %% [markdown]
# Исходя из личного опыта, уровни B1, B2 были изменены на:
# * `Before sunrise` - B1;
# * `Before sunset` - B1;
# * `Bridget Jones diary` - B1;
# * `Catch me if you can` - B2;
# * `Lion` - B2;
# * `The Shawshank redemption` - B2;
# * `The graduate` - B2;
# * `The lord of the rings` - B1.

# %%
movie_labels['level'] = movie_labels['level'].str.replace('A2/A2+', 'A2', regex=False)

# %% [markdown]
# Уровни A2/A2+ были изменены на A2.

# %%
movie_labels['level'].value_counts()
# Out:
# B2    105
# B1     58
# C1     40
# A2     34
# Name: level, dtype: int64

# %% [markdown]
# ## Объединение датафеймов

# %%
df = pd.merge(subtitles, movie_labels, how='outer', on=['movie'])

# %%
display(df.info())
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 283 entries, 0 to 282
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   data     274 non-null    object
#  1   movie    283 non-null    object
#  2   level_x  274 non-null    object
#  3   level_y  237 non-null    object
# dtypes: object(4)
# memory usage: 11.1+ KB
# None
#                                                 data  \
# 0  1\n00:00:03,169 --> 00:00:05,171\n( bugs chitt...
# 1  1\n00:00:03,045 --> 00:00:05,047\n- ( birds ch...
# 2  1\n00:00:03,003 --> 00:00:04,671\n( thunder ru...
# 3  1\n00:00:03,045 --> 00:00:05,422\n( birds chir...
# 4  1\n00:00:03,420 --> 00:00:04,922\n- ( walkie-t...
#
#                                                movie level_x level_y
# 0      the walking dead-s01e01-days gone bye.english      A2      A2
# 1               the walking dead-s01e02-guts.english      A2      A2
# 2  the walking dead-s01e03-tell it to the frogs.e...      A2      A2
# 3              the walking dead-s01e04-vatos.english      A2      A2
# 4           the walking dead-s01e05-wildfire.english      A2      A2

# %%
display(df.describe())
df.isna().sum()
# Out:
#                                                      data  \
# count                                                 274
# unique                                                274
# top     1\n00:00:03,169 --> 00:00:05,171\n( bugs chitt...
# freq                                                    1
#
#                                                 movie    level_x level_y
# count                                             283        274     237
# unique                                            283          5       4
# top     the walking dead-s01e01-days gone bye.english  Unlabeled      B2
# freq                                                1        115     105
# data        9
# movie       0
# level_x     9
# level_y    46
# dtype: int64

# %% [markdown]
# ### data

# %%
df[df['data'].isna()]
# Out:
#     data                       movie level_x level_y
# 274  NaN  its_a_wonderful_life(1946)     NaN      A2
# 275  NaN  the secret life of pets.en     NaN      B2
# 276  NaN                   up (2009)     NaN      A2
# 277  NaN                 glass onion     NaN      B2
# 278  NaN               matilda(2022)     NaN      C1
# 279  NaN                bullet train     NaN      B1
# 280  NaN      thor: love and thunder     NaN      B2
# 281  NaN                   lightyear     NaN      B2
# 282  NaN                  the grinch     NaN      B1

# %% [markdown]
# В субтитрах обнаружены пропуски.

# %% [markdown]
# #### its_a_wonderful_life(1946)

# %%
df[df['movie'].str.contains('wonderful')]
# Out:
#                                                   data  \
# 207  1\n00:01:25,210 --> 00:01:28,004\nI owe everyt...
# 274                                                NaN
#
#                            movie    level_x level_y
# 207  it_s_a_wonderful_life(1946)  Unlabeled     NaN
# 274   its_a_wonderful_life(1946)        NaN      A2

# %%
df['level_x'].iloc[207] = df['level_y'].iloc[274]
df = df.drop(274, axis=0)
df = df.reset_index(drop=True)

# %% [markdown]
# Пропуск вызван другим написанием названия и был удален.

# %% [markdown]
# #### he secret life of pets.en

# %%
df[df['movie'].str.contains('pet')]
# Out:
#     data                       movie level_x level_y
# 274  NaN  the secret life of pets.en     NaN      B2

# %%
subs = open('Missing_subtitles/The.Secret.Life.of.Pets.2016.720p.BRRip.x264.AAC-ETRG.srt', 'r', encoding='ISO-8859-1')
df['data'].iloc[274] = subs.read()
subs.close()

# %% [markdown]
# Субтитры отсутствовали и были скачаны из https://subscene.com/subtitles/the-secret-life-of-pets/english/1440256

# %% [markdown]
# #### up (2009)

# %%
df[df['movie'].str.contains('up')]
# Out:
#                                                   data               movie  \
# 245  1\n00:00:29,500 --> 00:00:31,200\n(CROWD CHEER...  the_break-up(2006)
# 267  1\n00:00:46,040 --> 00:00:50,960\n{\i1}Movieto...            up(2009)
# 275                                                NaN           up (2009)
#
#        level_x level_y
# 245  Unlabeled      A2
# 267  Unlabeled     NaN
# 275        NaN      A2

# %%
df['level_x'].iloc[267] = df['level_y'].iloc[275]
df = df.drop(275, axis=0)
df = df.reset_index(drop=True)

# %% [markdown]
# Пропуск вызван другим написанием названия и был удален.

# %% [markdown]
# #### glass onion

# %%
df[df['movie'].str.contains('onion')]
# Out:
#     data        movie level_x level_y
# 275  NaN  glass onion     NaN      B2

# %%
subs = open('Missing_subtitles/Glass.Onion.A Knives.Out.Mystery.2022.1080p.NF.WEB-DL.DDP5.1.Atmos.x264.srt', 'r',  encoding='ISO-8859-1')
df['data'].iloc[275] = subs.read()
subs.close()

# %% [markdown]
# Субтитры отсутствовали и были скачаны из https://subscene.com/subtitles/glass-onion-a-knives-out-mystery/english/2960299

# %% [markdown]
# #### matilda(2022)

# %%
df[df['movie'].str.contains('matilda')]
# Out:
#                                                   data          movie  \
# 218  1\n00:00:21,688 --> 00:00:24,692\n<i><font col...  matilda(1996)
# 276                                                NaN  matilda(2022)
#
#        level_x level_y
# 218  Unlabeled      B1
# 276        NaN      C1

# %%
subs = open("Missing_subtitles/Roald Dahl's Matilda the Musical (2022).srt", 'r',  encoding='ISO-8859-1')
df['data'].iloc[276] = subs.read()
subs.close()

# %% [markdown]
# Субтитры отсутствовали и были скачаны из https://subscene.com/subtitles/roald-dahls-matilda-the-musical/english/2968073

# %% [markdown]
# #### bullet train

# %%
df[df['movie'].str.contains('train')]
# Out:
#     data         movie level_x level_y
# 277  NaN  bullet train     NaN      B1

# %%
subs = open('Missing_subtitles/Bullet.Train.Eng.2022.NoHI.srt', 'r',  encoding='ISO-8859-1')
df['data'].iloc[277] = subs.read()
subs.close()

# %% [markdown]
# Субтитры отсутствовали и были скачаны из https://subscene.com/subtitles/bullet-train/english/3035799

# %% [markdown]
# #### thor: love and thunder

# %%
df[df['movie'].str.contains('thor')]
# Out:
#     data                   movie level_x level_y
# 278  NaN  thor: love and thunder     NaN      B2

# %%
subs = open('Missing_subtitles/Thor.Love.and.Thunder.2022.1080p.WEBRip.X264.DD5.1.srt', 'r',  encoding='ISO-8859-1')
df['data'].iloc[278] = subs.read()
subs.close()

# %% [markdown]
# Субтитры отсутствовали и были скачаны из https://subscene.com/subtitles/thor-love-and-thunder/english/2878411

# %% [markdown]
# #### lightyear

# %%
df[df['movie'].str.contains('lightyear')]
# Out:
#     data      movie level_x level_y
# 279  NaN  lightyear     NaN      B2

# %%
subs = open('Missing_subtitles/Lightyear.2022.WEBRip.x264-PS.srt', 'r',  encoding='ISO-8859-1')
df['data'].iloc[279] = subs.read()
subs.close()

# %% [markdown]
# Субтитры отсутствовали и были скачаны из https://subscene.com/subtitles/lightyear/english/2857387

# %% [markdown]
# #### the grinch

# %%
df[df['movie'].str.contains('grinch')]
# Out:
#                                                   data  \
# 110  ï»¿1\r\n00:00:25,735 --> 00:00:26,736\r\nIllum...
# 280                                                NaN
#
#                                                  movie level_x level_y
# 110  the.grinch.2018.remux.1080p.blu-ray.avc.truehd...      B2     NaN
# 280                                         the grinch     NaN      B1

# %%
df = df.drop(280, axis=0)
df = df.reset_index(drop=True)

# %% [markdown]
# Пропуск вызван другим написанием названия и был удален.

# %% [markdown]
# #### Дубликаты

# %%
df['data'].duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### moive

# %%
df['movie'].duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### level

# %%
df[df['level_x'].isna()]
# Out:
#                                                   data  \
# 274  ï»¿1\n00:00:25,440 --> 00:00:27,908\n<b>(HUMMI...
# 275  ï»¿1\n00:00:26,458 --> 00:00:29,625\nNo, subje...
# 276  ï»¿1\n00:01:16,833 --> 00:01:20,333\n<i>My mum...
# 277  ï»¿1\n00:01:40,892 --> 00:01:43,634\nThe booms...
# 278  ï»¿1\n00:00:41,834 --> 00:00:43,877\nOh, great...
# 279  1\n00:01:42,895 --> 00:01:45,939\nBuzz Lightye...
#
#                           movie level_x level_y
# 274  the secret life of pets.en     NaN      B2
# 275                 glass onion     NaN      B2
# 276               matilda(2022)     NaN      C1
# 277                bullet train     NaN      B1
# 278      thor: love and thunder     NaN      B2
# 279                   lightyear     NaN      B2

# %%
df['level_x'] = df['level_x'].fillna(df['level_y'])

# %% [markdown]
# Пропуски значения уровня из первой таблицы были заполнены значением уровня из второй.

# %%
display(df['level_y'].unique())
df['level_x'].value_counts()
# Out:
# array(['A2', 'B1', nan, 'B2', 'C1'], dtype=object)
# Unlabeled    113
# B2           107
# C1            34
# B1            18
# A2             8
# Name: level_x, dtype: int64

# %%
indexes = df[(df['level_x'] == 'Unlabeled') & (df['level_y'].isna())].index
df[(df['level_x'] == 'Unlabeled') & (df['level_y'].isna())]
# Out:
#                                                   data  \
# 175  1\n00:00:05,299 --> 00:00:08,220\nwhat hi good...
# 176  ï»¿1\r\n00:00:07,216 --> 00:00:09,676\r\n[pres...
# 180  1\n00:00:18,040 --> 00:00:21,870\n[Music]\n\n2...
# 198  1\n00:00:01,130 --> 00:00:18,359\n[Music]\n\n2...
# 201  1\n00:01:22,065 --> 00:01:27,070\nI should've ...
# 231  1\n00:00:20,020 --> 00:00:42,009\n[Music]\n\n2...
# 240  1\n00:00:04,670 --> 00:00:18,579\n[Music]\n\n2...
# 271  1\n00:00:00,000 --> 00:00:21,179\n[Music]\n\n2...
#
#                                                  movie    level_x level_y
# 175                       breaking_bad_the_movie(2017)  Unlabeled     NaN
# 176  brenв.brown.the.call.to.courage.2019.720.nf.72...  Unlabeled     NaN
# 180                                             casper  Unlabeled     NaN
# 198                                 gogo_loves_english  Unlabeled     NaN
# 201      harry_potter_and_the_philosophers_stone(2001)  Unlabeled     NaN
# 231                                pride_and_prejudice  Unlabeled     NaN
# 240                                   the_ghost_writer  Unlabeled     NaN
# 271                 westworld_scenes_of_dr_robert_ford  Unlabeled     NaN

# %%
df['level_x'].iloc[indexes[0]] = 'B2'
df['level_x'].iloc[indexes[1]] = 'B2'
df['level_x'].iloc[indexes[2]] = 'A2'
df['level_x'].iloc[indexes[3]] = 'A2' #A1 not present in dataset
df['level_x'].iloc[indexes[4]] = 'A2'
df['level_x'].iloc[indexes[5]] = 'B2'
df['level_x'].iloc[indexes[6]] = 'B2'
df['level_x'].iloc[indexes[7]] = 'B2'

# %% [markdown]
# Обнаружены субтитры без информации об уровне в обоих датафреймах. Они были заполнены исходя из личного знания английского.

# %%
df['level_x'] = df[['level_x', 'level_y']].apply(lambda x: x['level_x'] if x['level_x'] != 'Unlabeled' else x['level_y'], axis=1)

# %% [markdown]
# Субтитры с неизвесным уровнем из первой таблицы были заполнены на основе информации во второй таблице.

# %%
df['level_x'].unique()
# Out:
# array(['A2', 'B1', 'B2', 'C1'], dtype=object)

# %%
df = df.drop(['level_y', 'movie'], axis=1)

# %%
df = df.rename(columns={'level_x': 'level'})

# %% [markdown]
# Столбец `'level_x` был переименован в `level`, столбцы `level_y` и `moive` были удалены.

# %%
df.head()
# Out:
#                                                 data level
# 0  1\n00:00:03,169 --> 00:00:05,171\n( bugs chitt...    A2
# 1  1\n00:00:03,045 --> 00:00:05,047\n- ( birds ch...    A2
# 2  1\n00:00:03,003 --> 00:00:04,671\n( thunder ru...    A2
# 3  1\n00:00:03,045 --> 00:00:05,422\n( birds chir...    A2
# 4  1\n00:00:03,420 --> 00:00:04,922\n- ( walkie-t...    A2

# %% [markdown]
# ## Обработка субтитров

# %%
def parse_subtitles(data):
    subtitle_generator = srt.parse(data, ignore_errors=True);
    subs = list(subtitle_generator)
    subs_text = []
    for i in range(len(subs)):
        subs_text.append(subs[i].content)
    
    return(' '.join(subs_text))

# %% [markdown]
# Функция `parse subtitles` переводит субтитры в текст без разбивки по времени.

# %%
def remove_html_tags(text):
    import re
    clean = re.compile('<.*?>')
    return re.sub(clean, '', text)

# %% [markdown]
# Функция `remove_html_tags` удаляет HTML теги, присутствующие в некоторых субтитрах.

# %%
def tokenize_and_clean(data):
    data_tokenized = nltk.word_tokenize(data)
    stopwords = nltk.corpus.stopwords.words('english')
    data_cleaned = [word for word in data_tokenized if word.lower() not in stopwords]
    data_cleaned = [word.lower() for word in data_cleaned if word.isalpha()]
    lemm = WordNetLemmatizer()
    data_lemmatized = [lemm.lemmatize(w) for w in data_cleaned]
    return data_lemmatized

# %% [markdown]
# Функция `tokenize_and_clean` производит токенизацию, удаление стоп-слов, очистку от неальфавитных символов и лемматизацию.

# %%
df['data'] = df['data'].apply(parse_subtitles) 
df['data'] = df['data'].apply(remove_html_tags)
df['data'] = df['data'].apply(tokenize_and_clean)

# %%
level_a2 = df[df['level'] == 'A2']['data'].values
level_a2 = np.concatenate(level_a2, axis=0)
level_b1 = df[df['level'] == 'B1']['data'].values
level_b1 = np.concatenate(level_b1, axis=0)
level_b2 = df[df['level'] == 'B2']['data'].values
level_b2 = np.concatenate(level_b2, axis=0)
level_c1 = df[df['level'] == 'C1']['data'].values
level_c1 = np.concatenate(level_c1, axis=0)

# %% [markdown]
# Для последующего анализа были созданы переменные, содержащие все субтитры для каждого уровня.

# %% [markdown]
# # Исследовательский анализ данных

# %% [markdown]
# ## level

# %%
level_counts = df.groupby('level')['level'].count()
fig, ax = plt.subplots(figsize = (12,12))
ax.grid(False)
fig.patch.set_facecolor('w')
level_counts.plot(kind='pie', autopct='%1.1f%%',  textprops={'fontsize': 14})
# Out:
# <Axes: ylabel='level'>

# %% [markdown]
# Наблюдается дисбаланс классов, что повлияло на выбор метрики F1 macro, которая в отличие от F1 micro дает равный вес каждому классу.

# %% [markdown]
# ## data

# %%
plt.figure(figsize=(12, 20))
wordcloud = WordCloud(collocations=False, stopwords=STOPWORDS, background_color='black').generate(' '.join(level_a2))
plt.imshow(wordcloud)
plt.axis("off")
plt.title('A2')
plt.show()

# %%
plt.figure(figsize=(12, 20))
wordcloud = WordCloud(collocations=False, stopwords=STOPWORDS, background_color='black').generate(' '.join(level_b1))
plt.imshow(wordcloud)
plt.axis("off")
plt.title('B1')
plt.show()

# %%
plt.figure(figsize=(12, 20))
wordcloud = WordCloud(collocations=False, stopwords=STOPWORDS, background_color='black').generate(' '.join(level_b2))
plt.imshow(wordcloud)
plt.axis("off")
plt.title('B2')
plt.show()

# %%
plt.figure(figsize=(12, 20))
wordcloud = WordCloud(collocations=False, stopwords=STOPWORDS, background_color='black').generate(' '.join(level_c1))
plt.imshow(wordcloud)
plt.axis("off")
plt.title('C1')
plt.show()

# %% [markdown]
# У всех уровней схожие частые слова. Использование метода tf-idf поможет выделить более важные слова.

# %% [markdown]
# # Обучение моделей

# %%
predictions_list = []

# %%
X = df['data'].apply(' '.join)
y = df['level']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y,  random_state=1)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.25, stratify=y_train, random_state=1)

# %%
tfidf_vectorizer = TfidfVectorizer()
tfidf_vectorizer.fit(X_train)
X_train = tfidf_vectorizer.transform(X_train)
X_val = tfidf_vectorizer.transform(X_val)
X_test = tfidf_vectorizer.transform(X_test)

# %% [markdown]
# ## Logistic Regression

# %%
parameters = {
    'penalty' : [None, 'l2'], 
    'C'       : [1.0, 10.0, 100.0],
    'solver'  : ['newton-cg', 'lbfgs', 'sag'],
    'fit_intercept' : [True, False],
    'multi_class' : ['multinomial'],
    'random_state': [123]
}

# %%
model = LogisticRegression()
grid = GridSearchCV(model, param_grid=parameters, scoring='f1_macro', error_score='raise')

# %%
grid.fit(X_train, y_train);
grid.best_params_
# Out:
# {'C': 1.0,
#  'fit_intercept': True,
#  'multi_class': 'multinomial',
#  'penalty': None,
#  'random_state': 123,
#  'solver': 'lbfgs'}

# %%
predictions = grid.predict(X_val)
print('f1_macro =', f1_score(y_val, predictions, average='macro'))
predictions_list.append(f1_score(y_val, predictions, average='macro'))
# Out:
# f1_macro = 0.561111111111111

# %% [markdown]
# ## Random Forest

# %%
parameters = { 
    'n_estimators': [200, 500, 700],
    'max_depth' : [2, 5, 10, 20],
    'criterion' : ['gini', 'entropy'],
    'random_state' : [123]
}

# %%
model = RandomForestClassifier()
grid = GridSearchCV(model, param_grid=parameters, scoring='f1_macro', error_score='raise')

# %%
grid.fit(X_train, y_train);
grid.best_params_
# Out:
# {'criterion': 'entropy',
#  'max_depth': 10,
#  'n_estimators': 200,
#  'random_state': 123}

# %%
predictions = grid.predict(X_val)
print('f1_macro =', f1_score(y_val, predictions, average='macro'))
predictions_list.append(f1_score(y_val, predictions, average='macro'))
# Out:
# f1_macro = 0.21108058608058605

# %% [markdown]
# ## XGBoost

# %%
parameters = {
    'n_estimators' : [200, 500, 700],
    'max_depth' : [2, 5, 10, 20],
    'learning_rate' : [0.1, 0.01, 0.05],
    'random_state' : [123]
}

# %%
encoder = LabelEncoder()
encoder.fit(y_train)
y_train_enc = encoder.transform(y_train)
y_val_enc = encoder.transform(y_val)

# %% [markdown]
# XGBoost требует порядковое кодирование целевого столбца.

# %%
model = xgb.XGBClassifier()
grid = GridSearchCV(model, param_grid=parameters, scoring='f1_macro', error_score='raise') #imbalanced dataset, using F1 macro

# %%
grid.fit(X_train, y_train_enc);
grid.best_params_
# Out:
# {'learning_rate': 0.01,
#  'max_depth': 5,
#  'n_estimators': 500,
#  'random_state': 123}

# %%
predictions = grid.predict(X_val)
print('f1_macro =', f1_score(y_val_enc, predictions, average='macro'))
predictions_list.append(f1_score(y_val_enc, predictions, average='macro'))
# Out:
# f1_macro = 0.5107597716293368

# %% [markdown]
# # Анализ результатов и выводы

# %%
models = ['Logistic regression', 'Random forest', 'XGBoost']

# %%
sns.lineplot(x=models, y=predictions_list)
plt.xlabel('Модели')
plt.ylabel('F1 macro')
# Out:
# Text(0, 0.5, 'F1 macro')

# %%
model = LogisticRegression(C=1.0, fit_intercept=True, multi_class='multinomial', penalty=None, random_state=123, solver='lbfgs')
model.fit(X_train, y_train)
predictions = model.predict(X_test)
print('f1 macro =', f1_score(y_test, predictions, average='macro'))
# Out:
# f1 macro = 0.7339423648247178

# %% [markdown]
# Наилучший результат показала модель LogisticRegression, с результатом на тестовой выборке `F1 macro` = 0.7339423648247178.

# %% [markdown]
# # ToDo

# %% [markdown]
# * рассмотреть модели на основе трансформеров;
# * дополнить датасет новыми субитрами;
# * объеденить уровни языка.
